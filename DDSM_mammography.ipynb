# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !sudo apt-get install ruby-full
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   fonts-lato javascript-common libgmp-dev libgmpxx4ldbl libjs-jquery
#   libruby2.5 rake ri ruby ruby-dev ruby-did-you-mean ruby-minitest
#   ruby-net-telnet ruby-power-assert ruby-test-unit ruby2.5 ruby2.5-dev
#   ruby2.5-doc rubygems-integration
# Suggested packages:
#   apache2 | lighttpd | httpd gmp-doc libgmp10-doc libmpfr-dev bundler
# The following NEW packages will be installed:
#   fonts-lato javascript-common libgmp-dev libgmpxx4ldbl libjs-jquery
#   libruby2.5 rake ri ruby ruby-dev ruby-did-you-mean ruby-full ruby-minitest
#   ruby-net-telnet ruby-power-assert ruby-test-unit ruby2.5 ruby2.5-dev
#   ruby2.5-doc rubygems-integration
# 0 upgraded, 20 newly installed, 0 to remove and 39 not upgraded.
# Need to get 8,370 kB of archives.
# After this operation, 48.2 MB of additional disk space will be used.
# ...

# %%
# !git clone https://github.com/topiaruss/ddsm.git
# Out:
# Cloning into 'ddsm'...
# remote: Enumerating objects: 102, done.
# remote: Total 102 (delta 0), reused 0 (delta 0), pack-reused 102
# Receiving objects: 100% (102/102), 1.42 MiB | 7.81 MiB/s, done.
# Resolving deltas: 100% (46/46), done.

# %%
# !/content/ddsm/ddsm-software/jpeg -d -s /content/drive/MyDrive/INDIGO_MLR/CancerDeMama/figment.csee.usf.edu/pub/DDSM/cases/normals/normal_01/case0002/A_0002_1.LEFT_CC.LJPEG
# Out:
# Caution: precision type: 16 not 8 or 12.
# > GW:1979  GH:4349  R:0
# >> C:1  N:/content/drive/MyDrive/INDIGO_MLR/CancerDeMama/figment.csee.usf.edu/pub/DDSM/cases/normals/normal_01/case0002/A_0002_1.LEFT_CC.LJPEG.1  W:1979  H:4349  hf:1  vf:1

# %%
from matplotlib import pyplot as plt
import numpy as np
from io import StringIO
from PIL import *

scene_infile = open('/content/drive/MyDrive/INDIGO_MLR/CancerDeMama/figment.csee.usf.edu/pub/DDSM/cases/normals/normal_01/case0002/A_0002_1.LEFT_CC.LJPEG.1','rb')
scene_image_array = np.fromfile(scene_infile, dtype=np.uint16)
scene_image = Image.frombuffer("I",[1979, 4349],
                                 scene_image_array.astype('I'),
                                 'raw','I',0,1)
plt.figure(figsize=(8,16))
plt.imshow(np.array(scene_image), cmap='gray')
plt.show()

# %%
# %%bash
# cd /content/ddsm/ddsm-software/
# g++ -Wall -O2 ddsmraw2pnm.c -o ddsmraw2pnm /content/drive/MyDrive/INDIGO_MLR/CancerDeMama/figment.csee.usf.edu/pub/DDSM/cases/normals/normal_01/case0002/A_0002_1.LEFT_CC.LJPEG.1
# Out:
# ddsmraw2pnm.c: In function ‘int makePnmFile(FILE*, FILE*, int, int, bool (*)(unsigned int*, unsigned int))’:
# ddsmraw2pnm.c:341:65: warning: format not a string literal and no format arguments [-Wformat-security]
#    fprintf(output, (getPnmCommentString(calibrationFunc)).c_str());
#                                                                  ^
# ddsmraw2pnm.c:378:12: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’, declared with attribute warn_unused_result [-Wunused-result]
#        fread(thisByte, 1, 1, input);
#        ~~~~~^~~~~~~~~~~~~~~~~~~~~~~
# /content/drive/MyDrive/INDIGO_MLR/CancerDeMama/figment.csee.usf.edu/pub/DDSM/cases/normals/normal_01/case0002/A_0002_1.LEFT_CC.LJPEG.1: file not recognized: File format not recognized
# collect2: error: ld returned 1 exit status

# %%
# %%bash
# cd /content/ddsm/ddsm-software/
# ./get-ddsm-mammo A_1141_1.LEFT_MLO
# Out:
# ./get-ddsm-mammo:129:in `initialize': No such file or directory @ rb_sysopen - /ddsm_data/pub/DDSM/cases/cancers/cancer_06/case1141/A-1141-1.ics (Errno::ENOENT)
# 	from ./get-ddsm-mammo:129:in `open'
# 	from ./get-ddsm-mammo:129:in `get_image_dims_and_digitizer'
# 	from ./get-ddsm-mammo:172:in `do_get_image_info'
# 	from ./get-ddsm-mammo:187:in `get_image_info'
# 	from ./get-ddsm-mammo:278:in `main'
# 	from ./get-ddsm-mammo:336:in `<main>'

# %%
# !sudo apt-get install ruby-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ruby-dev is already the newest version (1:2.5.1).
# ruby-dev set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.

# %%
# !sudo gem install bundler
# Out:
# Fetching: bundler-2.2.23.gem (100%)
# ...
# Parsing documentation for bundler-2.2.23
# Installing ri documentation for bundler-2.2.23
# Done installing documentation for bundler after 4 seconds
# 1 gem installed
